# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
trends= pd.read_csv('shopping_trends.csv', index_col= 0)

# %%
trends.head()
# Out:
#              Age Age Group Gender Item Purchased  Category   Amount (USD)  \
# Customer ID
# 1             55    Senior   Male         Blouse  Clothing             53
# 2             19     Adult   Male        Sweater  Clothing             64
# 3             50    Senior   Male          Jeans  Clothing             73
# 4             21     Adult   Male        Sandals  Footwear             90
# 5             45     Midle   Male         Blouse  Clothing             49
#
#                   Location Size      Color  Season  Review Rating  \
# Customer ID
# 1                 Kentucky    L       Gray  Winter            3.1
# 2                    Maine    L     Maroon  Winter            3.1
# 3            Massachusetts    S     Maroon  Spring            3.1
# 4             Rhode Island    M     Maroon  Spring            3.5
# 5                   Oregon    M  Turquoise  Spring            2.7
#
#             Subscription Status Payment Method  Shipping Type  \
# Customer ID
# ...

# %%
trends.shape
# Out:
# (3900, 19)

# %%
trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 1 to 3900
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3900 non-null   int64
#  1   Age Group                 3900 non-null   object
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5    Amount (USD)             3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
# checking is there any null values are present or not
pd.isnull(trends).sum()
# Out:
# Age                         0
# Age Group                   0
# Gender                      0
# Item Purchased              0
# Category                    0
#  Amount (USD)               0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
trends.columns
# Out:
# Index(['Age', 'Age Group', 'Gender', 'Item Purchased', 'Category',
#        ' Amount (USD)', 'Location', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Payment Method', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Preferred Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
trends.describe()
# Out:
#                Age   Amount (USD)  Review Rating  Previous Purchases
# count  3900.000000    3900.000000    3900.000000         3900.000000
# mean     44.068462      59.764359       3.749949           25.351538
# std      15.207589      23.685392       0.716223           14.447125
# min      18.000000      20.000000       2.500000            1.000000
# 25%      31.000000      39.000000       3.100000           13.000000
# 50%      44.000000      60.000000       3.700000           25.000000
# 75%      57.000000      81.000000       4.400000           38.000000
# max      70.000000     100.000000       5.000000           50.000000

# %% [markdown]
# Exploratory Data Analysis

# %%
# using describe for particular columns only
trends[[' Amount (USD)','Review Rating']].describe()
# Out:
#         Amount (USD)  Review Rating
# count    3900.000000    3900.000000
# mean       59.764359       3.749949
# std        23.685392       0.716223
# min        20.000000       2.500000
# 25%        39.000000       3.100000
# 50%        60.000000       3.700000
# 75%        81.000000       4.400000
# max       100.000000       5.000000

# %% [markdown]
# # Exploratory Data Analysis
