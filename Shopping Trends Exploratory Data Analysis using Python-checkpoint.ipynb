# %%
# import python libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns

# %%
# import csv file
df= pd.read_csv('Shopping Trends Data.csv')

# %%
df
# Out:
#        index             Order ID  Cust ID Gender  Age Age Group        Date  \
# 0          1  171-1029312-3038738  1029312  Women   44    Middle  04-12-2022
# 1          2  405-2183842-2225946  2183842  Women   29     Young  04-12-2022
# 2          3  171-1641533-8921966  1641533  Women   67    Senior  04-12-2022
# 3          4  404-7490807-6300351  7490807  Women   20     Young  04-12-2022
# 4          5  403-9293516-4577154  9293516  Women   62    Senior  04-12-2022
# ...      ...                  ...      ...    ...  ...       ...         ...
# 31042  31043  405-4724097-1016369  4724097    Men   60    Senior  06-01-2022
# 31043  31044  405-4724097-1016369  4724097    Men   34    Middle  06-01-2022
# 31044  31045  408-3572295-5992330  3572295    Men   29     Young  06-01-2022
# 31045  31046  405-1423498-9705162  1423498    Men   46    Middle  06-01-2022
# 31046  31047  408-4694875-8249153  4694875    Men   36    Middle  06-01-2022
#
# ...

# %%
df.shape
# Out:
# (31047, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  object
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  object
#  4   Age               31047 non-null  int64
#  5   Age Group         31047 non-null  object
#  6   Date              31047 non-null  object
#  7   Month             31047 non-null  object
#  8   Status            31047 non-null  object
#  9   SKU               31047 non-null  object
#  10  Category          31047 non-null  object
#  11  Size              31047 non-null  object
#  12  Qty               31047 non-null  int64
#  13  currency          31047 non-null  object
#  14  Amount            31047 non-null  int64
#  15  ship-city         31047 non-null  object
# ...

# %%
# checking is there any null values are present or not
pd.isnull(df).sum()
# Out:
# index               0
# Order ID            0
# Cust ID             0
# Gender              0
# Age                 0
# Age Group           0
# Date                0
# Month               0
# Status              0
# SKU                 0
# Category            0
# Size                0
# Qty                 0
# currency            0
# Amount              0
# ship-city           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# B2B                 0
# dtype: int64

# %%
# checking is there 
duplicate_record= df.duplicated()
print(duplicate_record)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31042    False
# 31043    False
# 31044    False
# 31045    False
# 31046    False
# Length: 31047, dtype: bool

# %%
df.drop_duplicates(inplace= True)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Cust ID', 'Gender', 'Age', 'Age Group', 'Date',
#        'Month', 'Status', 'SKU', 'Category', 'Size', 'Qty', 'currency',
#        'Amount', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country',
#        'B2B'],
#       dtype='object')

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#              index       Cust ID           Age           Qty        Amount  \
# count  31047.00000  3.104700e+04  31047.000000  31047.000000  31047.000000
# mean   15524.00000  4.936824e+06     39.496570      1.006120    682.074822
# std     8962.64124  2.900678e+06     15.117233      0.094088    268.582173
# min        1.00000  8.950000e+02     18.000000      1.000000    229.000000
# 25%     7762.50000  2.416471e+06     28.000000      1.000000    486.000000
# 50%    15524.00000  4.909885e+06     37.000000      1.000000    646.000000
# 75%    23285.50000  7.454182e+06     47.000000      1.000000    794.000000
# max    31047.00000  9.999233e+06     78.000000      5.000000   3036.000000
#
#        ship-postal-code
# count      31047.000000
# mean      460474.587206
# std       198116.733009
# min       110001.000000
# 25%       313001.000000
# 50%       500028.000000
# 75%       600040.000000
# max       855117.000000

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Gender

# %%
# plotting bar chart for gender and its count
gb= df.groupby(['Gender'], as_index= False) ['Order ID'].count().sort_values(by= 'Gender', ascending= False)
ax = plt.pie(gb['Order ID'], labels=gb['Gender'], autopct='%1.1f%%', startangle=140, colors=['red', 'blue'])
plt.show()

# %%
# now we will check that whether male or female who has spent more amount.
gb= df.groupby(['Gender'], as_index= False) ['Amount'].sum().sort_values(by= 'Amount', ascending= False)
ax= sns.barplot(x= 'Gender', y='Amount', data= gb, hue= 'Gender')
sns.set(rc={'figure.figsize':(5,5)})
plt.title('Gender Vs Amount')
# Out:
# Text(0.5, 1.0, 'Gender Vs Amount')

# %% [markdown]
# **from above graphs we can conclude that Female customers are more as compared to male customers also they are spending more money or we can say that
# they have high purchasing power**

# %% [markdown]
# ## Age Group

# %%
# plotting count plot to check count of gender in each age group
ax = sns.countplot(x='Age Group', data = df, hue= 'Gender')
plt.title('Age Group')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# now we will check that which age group has spent more amount.
gb= df.groupby(['Age Group'], as_index= False) ['Amount'].sum().sort_values(by= 'Amount', ascending= False)
ax= sns.barplot(x= 'Age Group', y='Amount', data= gb, hue = 'Age Group')
plt.title('Age Group Vs Amount')
# Out:
# Text(0.5, 1.0, 'Age Group Vs Amount')

# %% [markdown]
# **from above graphs we can conclude that most of the customers are of middle age group and also the females of middle age group are
# more as compared to that of male**

# %% [markdown]
# ## Month

# %%
# plotting countplot to know orders per month
ax = sns.countplot(x='Month', data = df, hue= 'Month',order= df['Month'].value_counts().index)
plt.title('Month')
for bars in ax.containers:
    ax.bar_label(bars)
sns.set(rc={'figure.figsize':(10,5)})

# %%
# now we will check that which age group has spent more amount.
gb= df.groupby(['Month'], as_index= False) ['Amount'].sum().sort_values(by= 'Amount', ascending= False)
ax= sns.barplot(x= 'Month', y='Amount', data= gb, hue = 'Month')
plt.title('Month Vs Amount')
sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# **from above graphs we can conclude that the most orders are recieved in month march , february and january but the most revenue was generated in month march, february and april**

# %% [markdown]
# ## Status

# %%
# plotting countplot to know status of orders
gb= df.groupby(['Status'], as_index= False) ['Order ID'].count().sort_values(by= 'Status', ascending= False)
ax = plt.pie(gb['Order ID'], labels=gb['Status'], autopct='%1.1f%%', startangle=140, colors=['red', 'orange', 'green', 'blue'])
plt.show()

# %% [markdown]
# **from above graph we can see that 92.3% of total orders were delievered**

# %% [markdown]
# ## Category

# %%
# plotting countplot to know category with most sales
ax = sns.countplot(x='Category', data = df, hue= 'Category',order= df['Category'].value_counts().index)
plt.title('Category')
for bars in ax.containers:
    ax.bar_label(bars)
sns.set(rc={'figure.figsize':(20,5)})

# %%
# now we will check that which category has generated high revenue
gb= df.groupby(['Category'], as_index= False) ['Amount'].sum().sort_values(by= 'Amount', ascending= False)
ax= sns.barplot(x= 'Category', y='Amount', data= gb, hue = 'Category')
plt.title('Category Vs Amount')
sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# **from above graphs we can conclude that most sold products are of category Set**

# %% [markdown]
# ## Size

# %%
# plotting countplot to know Size with most sales
gb= df.groupby(['Size'], as_index= False) ['Order ID'].count().sort_values(by= 'Order ID', ascending= False)
ax= sns.barplot(x= 'Size', y='Order ID', data= gb, hue = 'Size')
plt.title('Size')
sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# **from above graph we can say that most sold sizes are medium, large and XL respectively**

# %% [markdown]
# ## State

# %%
# plotting countplot to know States with high sales
gb= df.groupby(['ship-state'], as_index= False) ['Order ID'].count().sort_values(by= 'Order ID', ascending= False).head(12)
ax= sns.barplot(x= 'ship-state', y='Order ID', data= gb, hue = 'ship-state')
plt.title('State')
sns.set(rc={'figure.figsize':(20,5)})

# %%
gb= df.groupby(['ship-state'], as_index= False) ['Amount'].count().sort_values(by= 'Amount', ascending= False).head(12)
ax= sns.barplot(x= 'ship-state', y='Amount', data= gb, hue = 'ship-state')
plt.title('State Vs Amount')
sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# **from above graphs we can conclude that Maharshta, Karnataka, Uttar Pradesh are top 3 states from which most of the orders are recieved and most of the revenue is generated**

# %% [markdown]
# ## City

# %%
# plotting countplot to know cities with high sales
gb= df.groupby(['ship-city'], as_index= False) ['Order ID'].count().sort_values(by= 'Order ID', ascending= False).head(12)
ax= sns.lineplot(x= 'ship-city', y='Order ID', data= gb)
plt.title('City')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
gb= df.groupby(['ship-city'], as_index= False) ['Amount'].count().sort_values(by= 'Amount', ascending= False).head(12)
ax= sns.lineplot(x= 'ship-city', y= 'Amount',data= gb)
plt.title('City Vs Amount')
sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# **from above graphs we can conclude that Bengaluru, Hyderabad, New Delhi are the top 3 cities with high no. of orders and high revenue**

# %% [markdown]
# ### Conclusion

# %% [markdown]
# **Mostly women of middle age group approximately of 26-35 yrs from Maharshta, Karnataka, Uttar Pradesh are
# more likely to buy sets, kurtas and western dresses of majorly medium, large and XL**

# %% [markdown]
# **From above data we get to know about target customers of buissness, now we can use various
# marketing strategies to promote the products which are most likely to purchase by the target customer**

# %% [markdown]
# **we can give various discounts and offers to the sets, kurtas and western dresses brands also advertising the products on different social
# media platforms so that sales will get increase**

# %% [markdown]
# ### Thank you !
